# %% [markdown]
# <a href="https://colab.research.google.com/github/markuskunej/air-pollution-thesis/blob/master/training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # This file is used to train various models

# %% [markdown]
# ## Unpickle dataframes from google drive and store in df dictionary

# %%
import pandas as pd
import os
import glob

DATA_PATH = "/content/drive/MyDrive/Air_Pollution_Data/dataframes"
all_pickle_files = glob.glob(DATA_PATH + '/*.pkl')

dfs = {}

for pkl_file in all_pickle_files:
  loc_and_interval = os.path.basename(pkl_file).split(".")[0] # i.e. Y&E_15m
  dfs[loc_and_interval] = pd.read_pickle(pkl_file)

# %% [markdown]
# Split data from 2022-10-03 11:00:00 to 2022-10-04 11:00:00

# %%
for df_name in dfs:
  df1 = dfs[df_name][:'2022-10-03 11:00:00-04:00']
  df2 = dfs[df_name]['2022-10-04 11:00:00-04:00':]
  dfs[df_name] = {"July-Oct": df1, "Oct-Jan": df2}

# %%
# test for stationarity, difference if seasonality exists
# https://michael-fuchs-python.netlify.app/2020/10/29/time-series-analysis-regression-extension-techniques-for-forecasting-multivariate-variables/#stationarity
from statsmodels.tsa.stattools import adfuller

def Augmented_Dickey_Fuller_Test_func(timeseries , column_name):
    '''
    Calculates statistical values whether the available data are stationary or not 
    
    Args:
        series (float64): Values of the column for which stationarity is to be checked, numpy array of floats 
        column_name (str): Name of the column for which stationarity is to be checked
    
    Returns:
        p-value that indicates whether the data are stationary or not
    '''
    print (f'Results of Dickey-Fuller Test for column: {column_name}')
    adfTest = adfuller(timeseries, autolag='AIC')   # why AIC vs BIC, t-stat, etc.?
    dfResults = pd.Series(adfTest[0:4], index=['ADF Test Statistic','P-Value','# Lags Used','# Observations Used'])
    for key, value in adfTest[4].items():
       dfResults['Critical Value (%s)'%key] = value
    print (dfResults)
    if adfTest[1] <= 0.05:
        print()
        print("Conclusion:")
        print("Reject the null hypothesis")
        print('\033[92m' + "Data is stationary" + '\033[0m')
        return True
    else:
        print()
        print("Conclusion:")
        print("Fail to reject the null hypothesis")
        print('\033[91m' + "Data is non-stationary" + '\033[0m')
        return False

# check each column of df for seasonality
def adf_df_test(df):
  non_station_cols = []
  for name, col in df.iteritems():
    if not df[name].isnull().values.any():
      is_stationary = Augmented_Dickey_Fuller_Test_func(df[name],name)
      print('\n')
      if not is_stationary:
        # add column to list of non-stationary ones
        non_station_cols.append(name)
    else:
      # column contains NaN values, drop from dataframe
      print(df[name].isnull().sum())
      df.drop(columns=name, inplace=True)
      print("Dropping column " + name + " because it contains NaN values.")
      

  return non_station_cols

# %%
import numpy as np

non_stat_cols_dict = {}
# test each df for stationarity
for group in dfs:
  for split_df_names in dfs[group]:
    print("STARTING ADF TEST FOR " + group + "_" + split_df_names + '\n')
    non_station_cols = adf_df_test(dfs[group][split_df_names])
    non_stat_cols_dict[group + "_" + split_df_names] = non_station_cols
# Out:
# STARTING ADF TEST FOR Y&E_60m_July-Oct
#
# Results of Dickey-Fuller Test for column: CO
# ADF Test Statistic     -6.218195e+00
# P-Value                 5.302048e-08
# # Lags Used             2.400000e+01
# # Observations Used     1.709000e+03
# Critical Value (1%)    -3.434182e+00
# Critical Value (5%)    -2.863233e+00
# Critical Value (10%)   -2.567671e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: CO2
# ADF Test Statistic     -6.317823e+00
# P-Value                 3.118952e-08
# # Lags Used             2.400000e+01
# # Observations Used     1.709000e+03
# Critical Value (1%)    -3.434182e+00
# Critical Value (5%)    -2.863233e+00
# Critical Value (10%)   -2.567671e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: Humidity
# ADF Test Statistic        -5.006961
# P-Value                    0.000021
# # Lags Used               25.000000
# # Observations Used     1708.000000
# Critical Value (1%)       -3.434184
# Critical Value (5%)       -2.863234
# Critical Value (10%)      -2.567672
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: NO
# ADF Test Statistic     -6.350820e+00
# P-Value                 2.613638e-08
# # Lags Used             2.400000e+01
# # Observations Used     1.709000e+03
# Critical Value (1%)    -3.434182e+00
# Critical Value (5%)    -2.863233e+00
# Critical Value (10%)   -2.567671e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: NO2
# ADF Test Statistic     -5.655499e+00
# P-Value                 9.642135e-07
# # Lags Used             2.500000e+01
# # Observations Used     1.708000e+03
# Critical Value (1%)    -3.434184e+00
# Critical Value (5%)    -2.863234e+00
# Critical Value (10%)   -2.567672e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: Noise
# ADF Test Statistic        -4.245325
# P-Value                    0.000552
# # Lags Used               25.000000
# # Observations Used     1708.000000
# Critical Value (1%)       -3.434184
# Critical Value (5%)       -2.863234
# Critical Value (10%)      -2.567672
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: O3
# ADF Test Statistic        -5.051361
# P-Value                    0.000018
# # Lags Used               24.000000
# # Observations Used     1709.000000
# Critical Value (1%)       -3.434182
# Critical Value (5%)       -2.863233
# Critical Value (10%)      -2.567671
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: PM1
# ADF Test Statistic     -5.864230e+00
# P-Value                 3.354763e-07
# # Lags Used             9.000000e+00
# # Observations Used     1.724000e+03
# Critical Value (1%)    -3.434149e+00
# Critical Value (5%)    -2.863218e+00
# Critical Value (10%)   -2.567663e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: PM10
# ADF Test Statistic     -6.021118e+00
# P-Value                 1.492937e-07
# # Lags Used             9.000000e+00
# # Observations Used     1.724000e+03
# Critical Value (1%)    -3.434149e+00
# Critical Value (5%)    -2.863218e+00
# Critical Value (10%)   -2.567663e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: PM2
# ADF Test Statistic     -5.963265e+00
# P-Value                 2.015457e-07
# # Lags Used             9.000000e+00
# # Observations Used     1.724000e+03
# Critical Value (1%)    -3.434149e+00
# Critical Value (5%)    -2.863218e+00
# Critical Value (10%)   -2.567663e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: Pressure
# ADF Test Statistic     -6.739720e+00
# P-Value                 3.141229e-09
# # Lags Used             2.500000e+01
# # Observations Used     1.708000e+03
# Critical Value (1%)    -3.434184e+00
# Critical Value (5%)    -2.863234e+00
# Critical Value (10%)   -2.567672e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: Temperature
# ADF Test Statistic        -2.844058
# P-Value                    0.052251
# # Lags Used               24.000000
# # Observations Used     1709.000000
# Critical Value (1%)       -3.434182
# Critical Value (5%)       -2.863233
# Critical Value (10%)      -2.567671
# dtype: float64
#
# Conclusion:
# Fail to reject the null hypothesis
# Data is non-stationary
#
#
# Results of Dickey-Fuller Test for column: WindDirection
# ADF Test Statistic        -4.617658
# P-Value                    0.000120
# # Lags Used               14.000000
# # Observations Used     1719.000000
# Critical Value (1%)       -3.434160
# Critical Value (5%)       -2.863223
# Critical Value (10%)      -2.567666
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: WindSpeed
# ADF Test Statistic        -4.435720
# P-Value                    0.000256
# # Lags Used               25.000000
# # Observations Used     1708.000000
# Critical Value (1%)       -3.434184
# Critical Value (5%)       -2.863234
# Critical Value (10%)      -2.567672
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# 1423
# Dropping column NoiseLEQ because it contains NaN values.
# 1423
# Dropping column NoiseMax because it contains NaN values.
# 1423
# Dropping column WindGust because it contains NaN values.
# STARTING ADF TEST FOR Y&E_60m_Oct-Jan
#
# Results of Dickey-Fuller Test for column: CO
# ADF Test Statistic        -4.866925
# P-Value                    0.000040
# # Lags Used               26.000000
# # Observations Used     2100.000000
# Critical Value (1%)       -3.433468
# Critical Value (5%)       -2.862917
# Critical Value (10%)      -2.567503
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: CO2
# ADF Test Statistic        -3.922672
# P-Value                    0.001874
# # Lags Used               26.000000
# # Observations Used     2100.000000
# Critical Value (1%)       -3.433468
# Critical Value (5%)       -2.862917
# Critical Value (10%)      -2.567503
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: Humidity
# ADF Test Statistic     -6.462327e+00
# P-Value                 1.433025e-08
# # Lags Used             2.600000e+01
# # Observations Used     2.100000e+03
# Critical Value (1%)    -3.433468e+00
# Critical Value (5%)    -2.862917e+00
# Critical Value (10%)   -2.567503e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: NO
# ADF Test Statistic        -5.177306
# P-Value                    0.000010
# # Lags Used               24.000000
# # Observations Used     2102.000000
# Critical Value (1%)       -3.433465
# Critical Value (5%)       -2.862916
# Critical Value (10%)      -2.567503
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: NO2
# ADF Test Statistic        -4.941474
# P-Value                    0.000029
# # Lags Used               25.000000
# # Observations Used     2101.000000
# Critical Value (1%)       -3.433466
# Critical Value (5%)       -2.862917
# Critical Value (10%)      -2.567503
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# 2127
# Dropping column Noise because it contains NaN values.
# Results of Dickey-Fuller Test for column: O3
# ADF Test Statistic        -5.266798
# P-Value                    0.000006
# # Lags Used               24.000000
# # Observations Used     2102.000000
# Critical Value (1%)       -3.433465
# Critical Value (5%)       -2.862916
# Critical Value (10%)      -2.567503
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: PM1
# ADF Test Statistic     -5.841788e+00
# P-Value                 3.762527e-07
# # Lags Used             5.000000e+00
# # Observations Used     2.121000e+03
# Critical Value (1%)    -3.433437e+00
# Critical Value (5%)    -2.862904e+00
# Critical Value (10%)   -2.567496e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: PM10
# ADF Test Statistic        -5.439985
# P-Value                    0.000003
# # Lags Used               10.000000
# # Observations Used     2116.000000
# Critical Value (1%)       -3.433444
# Critical Value (5%)       -2.862907
# Critical Value (10%)      -2.567498
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: PM2
# ADF Test Statistic     -5.789348e+00
# P-Value                 4.913711e-07
# # Lags Used             9.000000e+00
# # Observations Used     2.117000e+03
# Critical Value (1%)    -3.433443e+00
# Critical Value (5%)    -2.862906e+00
# Critical Value (10%)   -2.567497e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: Pressure
# ADF Test Statistic        -5.208197
# P-Value                    0.000008
# # Lags Used               26.000000
# # Observations Used     2100.000000
# Critical Value (1%)       -3.433468
# Critical Value (5%)       -2.862917
# Critical Value (10%)      -2.567503
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: Temperature
# ADF Test Statistic        -3.916222
# P-Value                    0.001919
# # Lags Used               25.000000
# # Observations Used     2101.000000
# Critical Value (1%)       -3.433466
# Critical Value (5%)       -2.862917
# Critical Value (10%)      -2.567503
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: WindDirection
# ADF Test Statistic     -8.826385e+00
# P-Value                 1.818787e-14
# # Lags Used             4.000000e+00
# # Observations Used     2.122000e+03
# Critical Value (1%)    -3.433435e+00
# Critical Value (5%)    -2.862903e+00
# Critical Value (10%)   -2.567496e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: WindSpeed
# ADF Test Statistic        -5.576301
# P-Value                    0.000001
# # Lags Used               25.000000
# # Observations Used     2101.000000
# Critical Value (1%)       -3.433466
# Critical Value (5%)       -2.862917
# Critical Value (10%)      -2.567503
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: NoiseLEQ
# ADF Test Statistic        -5.145856
# P-Value                    0.000011
# # Lags Used               26.000000
# # Observations Used     2100.000000
# Critical Value (1%)       -3.433468
# Critical Value (5%)       -2.862917
# Critical Value (10%)      -2.567503
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: NoiseMax
# ADF Test Statistic        -5.318198
# P-Value                    0.000005
# # Lags Used               26.000000
# # Observations Used     2100.000000
# Critical Value (1%)       -3.433468
# Critical Value (5%)       -2.862917
# Critical Value (10%)      -2.567503
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: WindGust
# ADF Test Statistic        -5.611070
# P-Value                    0.000001
# # Lags Used               25.000000
# # Observations Used     2101.000000
# Critical Value (1%)       -3.433466
# Critical Value (5%)       -2.862917
# Critical Value (10%)      -2.567503
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# STARTING ADF TEST FOR Y&E_15m_July-Oct
#
# Results of Dickey-Fuller Test for column: CO
# ADF Test Statistic     -1.295328e+01
# P-Value                 3.341569e-24
# # Lags Used             6.000000e+00
# # Observations Used     6.929000e+03
# Critical Value (1%)    -3.431294e+00
# Critical Value (5%)    -2.861957e+00
# Critical Value (10%)   -2.566992e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: CO2
# ADF Test Statistic     -1.059826e+01
# P-Value                 6.267568e-19
# # Lags Used             4.000000e+00
# # Observations Used     6.931000e+03
# Critical Value (1%)    -3.431294e+00
# Critical Value (5%)    -2.861957e+00
# Critical Value (10%)   -2.566992e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: Humidity
# ADF Test Statistic     -1.147484e+01
# P-Value                 5.160988e-21
# # Lags Used             1.600000e+01
# # Observations Used     6.919000e+03
# Critical Value (1%)    -3.431295e+00
# Critical Value (5%)    -2.861958e+00
# Critical Value (10%)   -2.566992e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: NO
# ADF Test Statistic     -1.431664e+01
# P-Value                 1.159904e-26
# # Lags Used             2.800000e+01
# # Observations Used     6.907000e+03
# Critical Value (1%)    -3.431297e+00
# Critical Value (5%)    -2.861959e+00
# Critical Value (10%)   -2.566993e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: NO2
# ADF Test Statistic     -1.409626e+01
# P-Value                 2.667098e-26
# # Lags Used             3.300000e+01
# # Observations Used     6.902000e+03
# Critical Value (1%)    -3.431298e+00
# Critical Value (5%)    -2.861959e+00
# Critical Value (10%)   -2.566993e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: Noise
# ADF Test Statistic     -1.854620e+01
# P-Value                 2.094937e-30
# # Lags Used             3.500000e+01
# # Observations Used     6.900000e+03
# Critical Value (1%)    -3.431298e+00
# Critical Value (5%)    -2.861959e+00
# Critical Value (10%)   -2.566993e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: O3
# ADF Test Statistic     -1.408864e+01
# P-Value                 2.746676e-26
# # Lags Used             2.000000e+01
# # Observations Used     6.915000e+03
# Critical Value (1%)    -3.431296e+00
# Critical Value (5%)    -2.861958e+00
# Critical Value (10%)   -2.566993e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: PM1
# ADF Test Statistic     -7.323470e+00
# P-Value                 1.177540e-10
# # Lags Used             3.000000e+00
# # Observations Used     6.932000e+03
# Critical Value (1%)    -3.431294e+00
# Critical Value (5%)    -2.861957e+00
# Critical Value (10%)   -2.566992e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: PM10
# ADF Test Statistic     -7.734454e+00
# P-Value                 1.103146e-11
# # Lags Used             7.000000e+00
# # Observations Used     6.928000e+03
# Critical Value (1%)    -3.431294e+00
# Critical Value (5%)    -2.861957e+00
# Critical Value (10%)   -2.566992e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: PM2
# ADF Test Statistic     -7.628152e+00
# P-Value                 2.042389e-11
# # Lags Used             3.000000e+00
# # Observations Used     6.932000e+03
# Critical Value (1%)    -3.431294e+00
# Critical Value (5%)    -2.861957e+00
# Critical Value (10%)   -2.566992e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: Pressure
# ADF Test Statistic        -4.241495
# P-Value                    0.000560
# # Lags Used               32.000000
# # Observations Used     6903.000000
# Critical Value (1%)       -3.431298
# Critical Value (5%)       -2.861959
# Critical Value (10%)      -2.566993
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: Temperature
# ADF Test Statistic     -6.506686e+00
# P-Value                 1.126601e-08
# # Lags Used             3.500000e+01
# # Observations Used     6.900000e+03
# Critical Value (1%)    -3.431298e+00
# Critical Value (5%)    -2.861959e+00
# Critical Value (10%)   -2.566993e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: WindDirection
# ADF Test Statistic     -7.562983e+00
# P-Value                 2.976087e-11
# # Lags Used             1.200000e+01
# # Observations Used     6.923000e+03
# Critical Value (1%)    -3.431295e+00
# Critical Value (5%)    -2.861958e+00
# Critical Value (10%)   -2.566992e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: WindSpeed
# ADF Test Statistic     -1.073648e+01
# P-Value                 2.890336e-19
# # Lags Used             1.700000e+01
# # Observations Used     6.918000e+03
# Critical Value (1%)    -3.431296e+00
# Critical Value (5%)    -2.861958e+00
# Critical Value (10%)   -2.566992e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# 5693
# Dropping column NoiseLEQ because it contains NaN values.
# 5693
# Dropping column NoiseMax because it contains NaN values.
# 5694
# Dropping column WindGust because it contains NaN values.
# STARTING ADF TEST FOR Y&E_15m_Oct-Jan
#
# Results of Dickey-Fuller Test for column: CO
# ADF Test Statistic     -7.364708e+00
# P-Value                 9.301741e-11
# # Lags Used             3.500000e+01
# # Observations Used     8.469000e+03
# Critical Value (1%)    -3.431122e+00
# Critical Value (5%)    -2.861881e+00
# Critical Value (10%)   -2.566952e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: CO2
# ADF Test Statistic     -6.231087e+00
# P-Value                 4.951539e-08
# # Lags Used             3.400000e+01
# # Observations Used     8.470000e+03
# Critical Value (1%)    -3.431122e+00
# Critical Value (5%)    -2.861881e+00
# Critical Value (10%)   -2.566952e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: Humidity
# ADF Test Statistic     -1.011573e+01
# P-Value                 9.736200e-18
# # Lags Used             9.000000e+00
# # Observations Used     8.495000e+03
# Critical Value (1%)    -3.431120e+00
# Critical Value (5%)    -2.861880e+00
# Critical Value (10%)   -2.566951e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: NO
# ADF Test Statistic     -1.247535e+01
# P-Value                 3.177469e-23
# # Lags Used             2.400000e+01
# # Observations Used     8.480000e+03
# Critical Value (1%)    -3.431121e+00
# Critical Value (5%)    -2.861881e+00
# Critical Value (10%)   -2.566951e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: NO2
# ADF Test Statistic     -1.333643e+01
# P-Value                 6.039371e-25
# # Lags Used             7.000000e+00
# # Observations Used     8.497000e+03
# Critical Value (1%)    -3.431120e+00
# Critical Value (5%)    -2.861880e+00
# Critical Value (10%)   -2.566951e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# 8505
# Dropping column Noise because it contains NaN values.
# Results of Dickey-Fuller Test for column: O3
# ADF Test Statistic     -1.072249e+01
# P-Value                 3.125112e-19
# # Lags Used             1.200000e+01
# # Observations Used     8.492000e+03
# Critical Value (1%)    -3.431120e+00
# Critical Value (5%)    -2.861880e+00
# Critical Value (10%)   -2.566951e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: PM1
# ADF Test Statistic     -6.405718e+00
# P-Value                 1.945594e-08
# # Lags Used             9.000000e+00
# # Observations Used     8.495000e+03
# Critical Value (1%)    -3.431120e+00
# Critical Value (5%)    -2.861880e+00
# Critical Value (10%)   -2.566951e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: PM10
# ADF Test Statistic     -6.038883e+00
# P-Value                 1.361029e-07
# # Lags Used             8.000000e+00
# # Observations Used     8.496000e+03
# Critical Value (1%)    -3.431120e+00
# Critical Value (5%)    -2.861880e+00
# Critical Value (10%)   -2.566951e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: PM2
# ADF Test Statistic     -6.300362e+00
# P-Value                 3.424066e-08
# # Lags Used             8.000000e+00
# # Observations Used     8.496000e+03
# Critical Value (1%)    -3.431120e+00
# Critical Value (5%)    -2.861880e+00
# Critical Value (10%)   -2.566951e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: Pressure
# ADF Test Statistic     -6.099612e+00
# P-Value                 9.908180e-08
# # Lags Used             3.200000e+01
# # Observations Used     8.472000e+03
# Critical Value (1%)    -3.431122e+00
# Critical Value (5%)    -2.861881e+00
# Critical Value (10%)   -2.566952e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: Temperature
# ADF Test Statistic        -3.765620
# P-Value                    0.003279
# # Lags Used               30.000000
# # Observations Used     8474.000000
# Critical Value (1%)       -3.431122
# Critical Value (5%)       -2.861881
# Critical Value (10%)      -2.566952
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: WindDirection
# ADF Test Statistic     -9.832169e+00
# P-Value                 5.003662e-17
# # Lags Used             1.100000e+01
# # Observations Used     8.493000e+03
# Critical Value (1%)    -3.431120e+00
# Critical Value (5%)    -2.861880e+00
# Critical Value (10%)   -2.566951e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: WindSpeed
# ADF Test Statistic     -8.735517e+00
# P-Value                 3.108025e-14
# # Lags Used             4.000000e+00
# # Observations Used     8.500000e+03
# Critical Value (1%)    -3.431120e+00
# Critical Value (5%)    -2.861880e+00
# Critical Value (10%)   -2.566951e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: NoiseLEQ
# ADF Test Statistic     -1.844176e+01
# P-Value                 2.160540e-30
# # Lags Used             3.700000e+01
# # Observations Used     8.467000e+03
# Critical Value (1%)    -3.431123e+00
# Critical Value (5%)    -2.861881e+00
# Critical Value (10%)   -2.566952e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: NoiseMax
# ADF Test Statistic     -1.736601e+01
# P-Value                 5.170597e-30
# # Lags Used             3.700000e+01
# # Observations Used     8.467000e+03
# Critical Value (1%)    -3.431123e+00
# Critical Value (5%)    -2.861881e+00
# Critical Value (10%)   -2.566952e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: WindGust
# ADF Test Statistic     -8.397956e+00
# P-Value                 2.271921e-13
# # Lags Used             4.000000e+00
# # Observations Used     8.500000e+03
# Critical Value (1%)    -3.431120e+00
# Critical Value (5%)    -2.861880e+00
# Critical Value (10%)   -2.566951e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# STARTING ADF TEST FOR Y&E_1m_July-Oct
#
# Results of Dickey-Fuller Test for column: CO
# ADF Test Statistic     -1.194255e+01
# P-Value                 4.507597e-22
# # Lags Used             6.600000e+01
# # Observations Used     1.039460e+05
# Critical Value (1%)    -3.430413e+00
# Critical Value (5%)    -2.861568e+00
# Critical Value (10%)   -2.566785e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: CO2
# ADF Test Statistic     -1.032411e+01
# P-Value                 2.956496e-18
# # Lags Used             6.500000e+01
# # Observations Used     1.039470e+05
# Critical Value (1%)    -3.430413e+00
# Critical Value (5%)    -2.861568e+00
# Critical Value (10%)   -2.566785e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: Humidity
# ADF Test Statistic     -9.180042e+00
# P-Value                 2.264848e-15
# # Lags Used             6.500000e+01
# # Observations Used     1.039470e+05
# Critical Value (1%)    -3.430413e+00
# Critical Value (5%)    -2.861568e+00
# Critical Value (10%)   -2.566785e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: NO
# ADF Test Statistic     -1.204640e+01
# P-Value                 2.658774e-22
# # Lags Used             6.400000e+01
# # Observations Used     1.039480e+05
# Critical Value (1%)    -3.430413e+00
# Critical Value (5%)    -2.861568e+00
# Critical Value (10%)   -2.566785e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: NO2
# ADF Test Statistic     -1.277964e+01
# P-Value                 7.463210e-24
# # Lags Used             5.900000e+01
# # Observations Used     1.039530e+05
# Critical Value (1%)    -3.430413e+00
# Critical Value (5%)    -2.861568e+00
# Critical Value (10%)   -2.566785e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: Noise
# ADF Test Statistic     -9.985195e+00
# P-Value                 2.064329e-17
# # Lags Used             6.900000e+01
# # Observations Used     1.039430e+05
# Critical Value (1%)    -3.430413e+00
# Critical Value (5%)    -2.861568e+00
# Critical Value (10%)   -2.566785e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: O3
# ADF Test Statistic     -1.007653e+01
# P-Value                 1.219664e-17
# # Lags Used             6.700000e+01
# # Observations Used     1.039450e+05
# Critical Value (1%)    -3.430413e+00
# Critical Value (5%)    -2.861568e+00
# Critical Value (10%)   -2.566785e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: PM1
# ADF Test Statistic     -7.139731e+00
# P-Value                 3.348420e-10
# # Lags Used             6.900000e+01
# # Observations Used     1.039430e+05
# Critical Value (1%)    -3.430413e+00
# Critical Value (5%)    -2.861568e+00
# Critical Value (10%)   -2.566785e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: PM10
# ADF Test Statistic     -7.662157e+00
# P-Value                 1.677528e-11
# # Lags Used             6.900000e+01
# # Observations Used     1.039430e+05
# Critical Value (1%)    -3.430413e+00
# Critical Value (5%)    -2.861568e+00
# Critical Value (10%)   -2.566785e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: PM2
# ADF Test Statistic     -7.436972e+00
# P-Value                 6.146862e-11
# # Lags Used             6.900000e+01
# # Observations Used     1.039430e+05
# Critical Value (1%)    -3.430413e+00
# Critical Value (5%)    -2.861568e+00
# Critical Value (10%)   -2.566785e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: Pressure
# ADF Test Statistic          -1.941061
# P-Value                      0.312998
# # Lags Used                 69.000000
# # Observations Used     103943.000000
# Critical Value (1%)         -3.430413
# Critical Value (5%)         -2.861568
# Critical Value (10%)        -2.566785
# dtype: float64
#
# Conclusion:
# Fail to reject the null hypothesis
# Data is non-stationary
#
#
# Results of Dickey-Fuller Test for column: Temperature
# ADF Test Statistic     -7.612222e+00
# P-Value                 2.239455e-11
# # Lags Used             6.900000e+01
# # Observations Used     1.039430e+05
# Critical Value (1%)    -3.430413e+00
# Critical Value (5%)    -2.861568e+00
# Critical Value (10%)   -2.566785e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# 403
# Dropping column WindDirection because it contains NaN values.
# Results of Dickey-Fuller Test for column: WindSpeed
# ADF Test Statistic     -1.077743e+01
# P-Value                 2.300664e-19
# # Lags Used             4.900000e+01
# # Observations Used     1.039630e+05
# Critical Value (1%)    -3.430413e+00
# Critical Value (5%)    -2.861568e+00
# Critical Value (10%)   -2.566785e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# 85370
# Dropping column NoiseLEQ because it contains NaN values.
# 85370
# Dropping column NoiseMax because it contains NaN values.
# 85666
# Dropping column WindGust because it contains NaN values.
# STARTING ADF TEST FOR Y&E_1m_Oct-Jan
#
# Results of Dickey-Fuller Test for column: CO
# ADF Test Statistic     -1.112695e+01
# P-Value                 3.355667e-20
# # Lags Used             7.200000e+01
# # Observations Used     1.274880e+05
# Critical Value (1%)    -3.430401e+00
# Critical Value (5%)    -2.861563e+00
# Critical Value (10%)   -2.566782e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: CO2
# ADF Test Statistic     -1.015606e+01
# P-Value                 7.724218e-18
# # Lags Used             6.500000e+01
# # Observations Used     1.274950e+05
# Critical Value (1%)    -3.430401e+00
# Critical Value (5%)    -2.861563e+00
# Critical Value (10%)   -2.566782e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: Humidity
# ADF Test Statistic     -9.625844e+00
# P-Value                 1.661575e-16
# # Lags Used             5.900000e+01
# # Observations Used     1.275010e+05
# Critical Value (1%)    -3.430401e+00
# Critical Value (5%)    -2.861563e+00
# Critical Value (10%)   -2.566782e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: NO
# ADF Test Statistic     -1.435796e+01
# P-Value                 9.959930e-27
# # Lags Used             7.200000e+01
# # Observations Used     1.274880e+05
# Critical Value (1%)    -3.430401e+00
# Critical Value (5%)    -2.861563e+00
# Critical Value (10%)   -2.566782e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: NO2
# ADF Test Statistic     -1.285118e+01
# P-Value                 5.348623e-24
# # Lags Used             6.600000e+01
# # Observations Used     1.274940e+05
# Critical Value (1%)    -3.430401e+00
# Critical Value (5%)    -2.861563e+00
# Critical Value (10%)   -2.566782e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# 127561
# Dropping column Noise because it contains NaN values.
# Results of Dickey-Fuller Test for column: O3
# ADF Test Statistic     -9.620774e+00
# P-Value                 1.711456e-16
# # Lags Used             6.000000e+01
# # Observations Used     1.275000e+05
# Critical Value (1%)    -3.430401e+00
# Critical Value (5%)    -2.861563e+00
# Critical Value (10%)   -2.566782e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: PM1
# ADF Test Statistic     -6.963771e+00
# P-Value                 9.024059e-10
# # Lags Used             7.200000e+01
# # Observations Used     1.274880e+05
# Critical Value (1%)    -3.430401e+00
# Critical Value (5%)    -2.861563e+00
# Critical Value (10%)   -2.566782e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: PM10
# ADF Test Statistic     -6.545148e+00
# P-Value                 9.138693e-09
# # Lags Used             7.200000e+01
# # Observations Used     1.274880e+05
# Critical Value (1%)    -3.430401e+00
# Critical Value (5%)    -2.861563e+00
# Critical Value (10%)   -2.566782e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: PM2
# ADF Test Statistic     -6.796768e+00
# P-Value                 2.290411e-09
# # Lags Used             7.200000e+01
# # Observations Used     1.274880e+05
# Critical Value (1%)    -3.430401e+00
# Critical Value (5%)    -2.861563e+00
# Critical Value (10%)   -2.566782e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: Pressure
# ADF Test Statistic          -3.642423
# P-Value                      0.005000
# # Lags Used                 72.000000
# # Observations Used     127488.000000
# Critical Value (1%)         -3.430401
# Critical Value (5%)         -2.861563
# Critical Value (10%)        -2.566782
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: Temperature
# ADF Test Statistic          -4.741871
# P-Value                      0.000070
# # Lags Used                 71.000000
# # Observations Used     127489.000000
# Critical Value (1%)         -3.430401
# Critical Value (5%)         -2.861563
# Critical Value (10%)        -2.566782
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: WindDirection
# ADF Test Statistic     -1.229608e+01
# P-Value                 7.633935e-23
# # Lags Used             7.200000e+01
# # Observations Used     1.274880e+05
# Critical Value (1%)    -3.430401e+00
# Critical Value (5%)    -2.861563e+00
# Critical Value (10%)   -2.566782e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: WindSpeed
# ADF Test Statistic     -8.836543e+00
# P-Value                 1.713048e-14
# # Lags Used             6.700000e+01
# # Observations Used     1.274930e+05
# Critical Value (1%)    -3.430401e+00
# Critical Value (5%)    -2.861563e+00
# Critical Value (10%)   -2.566782e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: NoiseLEQ
# ADF Test Statistic     -1.426477e+01
# P-Value                 1.406742e-26
# # Lags Used             7.200000e+01
# # Observations Used     1.274880e+05
# Critical Value (1%)    -3.430401e+00
# Critical Value (5%)    -2.861563e+00
# Critical Value (10%)   -2.566782e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: NoiseMax
# ADF Test Statistic     -1.459413e+01
# P-Value                 4.267542e-27
# # Lags Used             7.200000e+01
# # Observations Used     1.274880e+05
# Critical Value (1%)    -3.430401e+00
# Critical Value (5%)    -2.861563e+00
# Critical Value (10%)   -2.566782e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary
#
#
# Results of Dickey-Fuller Test for column: WindGust
# ADF Test Statistic     -8.474591e+00
# P-Value                 1.446866e-13
# # Lags Used             6.800000e+01
# # Observations Used     1.274920e+05
# Critical Value (1%)    -3.430401e+00
# Critical Value (5%)    -2.861563e+00
# Critical Value (10%)   -2.566782e+00
# dtype: float64
#
# Conclusion:
# Reject the null hypothesis
# Data is stationary

# %%
print(non_stat_cols_dict)
# Out:
# {'Y&E_60m_July-Oct': ['Temperature'], 'Y&E_60m_Oct-Jan': [], 'Y&E_15m_July-Oct': [], 'Y&E_15m_Oct-Jan': [], 'Y&E_1m_July-Oct': ['Pressure'], 'Y&E_1m_Oct-Jan': []}

# %%
def train(df):
